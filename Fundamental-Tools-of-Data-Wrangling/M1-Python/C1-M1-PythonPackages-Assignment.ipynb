# %% [markdown]
# # Let's warm up your knowledge about Python Packages!

# %% [markdown]
# # random package

# %%
import random

# %% [markdown]
# ## Random Int
# > hint: use `random.randint()` or `random.randrange()`

# %% [markdown]
# ### Task: Generate a random positive integer less than 10.

# %%
print(random.randint(1,9))
# Out:
# 4

# %% [markdown]
# ### Task: Generate a random integer within 0 (inclusive) and 100 (inclusive)

# %%
print(random.randint(0,100))
# Out:
# 40

# %% [markdown]
# ### Task: Generate a random integer within a and b, where a and b are user entered integers and a $<=$ b

# %%
x = int(input('Ingresa un número entero: '))
y = int(input('Ingresa otro número entero: '))

if x <= y:
    print(random.randint(x, y))
else:
    print('Intenta de nuevo')
# Out:
# Ingresa un número entero:  2
# Ingresa otro número entero:  100
# 65

# %% [markdown]
# ## Random Float
# > hint: use `random.random()`, `random.uniform()`, or `random.gauss()`

# %% [markdown]
# ### Task: Generate a random float number between 0 and 1

# %%
print(random.random())
# Out:
# 0.6341821017873848

# %% [markdown]
# ### Task: Generate a random float number between 0 and 10.

# %%
print(random.random() * 10)
print(random.uniform(0, 10))
# Out:
# 3.671497426919348
# 6.716413299945937

# %% [markdown]
# ### Task: Generate a random float number between 5 and 10

# %%
print(random.uniform(5, 10))
# Out:
# 7.653204692803777

# %% [markdown]
# ### Task: Generate a random float number based on the Gaussian distribution

# %%
print(random.gauss(0, 1))
# Out:
# -0.02258369682525542

# %% [markdown]
# ## Random Datasets
#
# ### Genearte a list of 10 random floats within 0 and 1.

# %%
print([random.random() for x in range(10)])
# Out:
# [0.07410613608351269, 0.4358130631084862, 0.11278697066615118, 0.4378811744551442, 0.4761538854642696, 0.12977681680699216, 0.25484823621692443, 0.6198961566105623, 0.10283739929600377, 0.2529151561175135]

# %% [markdown]
# ### Generate a list of 10 random integers within 0 and 10.

# %%
print([random.randint(0,10) for x in range(10)])
# Out:
# [0, 6, 1, 10, 3, 0, 3, 8, 2, 7]

# %% [markdown]
# ### Generate a list of 10 numbers following normal distribution with 10 as mean, and 1 as standard derivation.

# %%
print([random.normalvariate(10,1) for x in range(10)])
# Out:
# [10.533695017947243, 9.667216875669837, 10.966206626779906, 10.58989252254383, 10.461636034227602, 8.44189735655202, 8.289741942860893, 9.92810221003519, 7.566139875681602, 8.069378924013186]

# %% [markdown]
# ## math module

# %%
import math

# %% [markdown]
# ### Task: return the ceiling, floor, absolute value of a user entered float

# %%
numero = float(input('Ingresa un número: '))

print(math.ceil(numero))
print(math.floor(numero))
print(abs(numero))
# Out:
# Ingresa un número:  -6855.5554
# -6855
# -6856
# 6855.5554

# %% [markdown]
# ### Task: return the factorial of a user entered positive integer

# %%
numero = int(input('Ingresa un número entero: '))

print(math.factorial(numero))
# Out:
# Ingresa un número entero:  8
# 40320

# %% [markdown]
# ### Task: return the square root, $log$, $log_2$, $log_{10}$ of a user entered positive float

# %%
numero = float(input('Ingresa un número positivo: '))

print(math.sqrt(numero))
print(math.log(numero))
print(math.log2(numero))
print(math.log(numero, 2))
print(math.log10(numero))
print(math.log(numero, 10))
# Out:
# Ingresa un número positivo:  4
# 2.0
# 1.3862943611198906
# 2.0
# 2.0
# 0.6020599913279624
# 0.6020599913279623
