# %% [markdown]
# # Lab Dictionary

# %% [markdown]
# ## Data We Want to Organize
# You are given a dataset as below represented as a list. You should organize them in the required data structure in following tasks.

# %%
SIZE = 48
names = ['STU' + str(i) for i in range(100,100+SIZE)]
names
# Out:
# ['STU100',
#  'STU101',
#  'STU102',
#  'STU103',
#  'STU104',
#  'STU105',
#  'STU106',
#  'STU107',
#  'STU108',
#  'STU109',
#  'STU110',
#  'STU111',
#  'STU112',
#  'STU113',
#  'STU114',
#  'STU115',
#  'STU116',
#  'STU117',
#  'STU118',
#  'STU119',
#  'STU120',
#  'STU121',
#  'STU122',
#  'STU123',
#  'STU124',
#  'STU125',
#  'STU126',
#  'STU127',
#  'STU128',
#  'STU129',
#  'STU130',
#  'STU131',
#  'STU132',
#  'STU133',
#  'STU134',
#  'STU135',
#  'STU136',
#  'STU137',
#  'STU138',
#  'STU139',
#  'STU140',
#  'STU141',
#  'STU142',
#  'STU143',
#  'STU144',
#  'STU145',
#  'STU146',
#  'STU147']

# %%
import random

scores1 = [random.randint(60, 100) for i in range(SIZE)]
scores1
# Out:
# [72,
#  85,
#  64,
#  61,
#  78,
#  88,
#  100,
#  99,
#  88,
#  65,
#  75,
#  96,
#  86,
#  82,
#  96,
#  85,
#  96,
#  83,
#  97,
#  85,
#  82,
#  88,
#  73,
#  67,
#  95,
#  76,
#  81,
#  78,
#  70,
#  70,
#  76,
#  72,
#  68,
#  88,
#  71,
#  82,
#  64,
#  81,
#  90,
#  100,
#  90,
#  83,
#  89,
#  98,
#  85,
#  65,
#  83,
#  66]

# %%
scores2 = [random.randint(60, 100) for i in range(SIZE)]
scores2
# Out:
# [94,
#  97,
#  93,
#  77,
#  67,
#  77,
#  100,
#  81,
#  97,
#  70,
#  82,
#  76,
#  66,
#  78,
#  89,
#  91,
#  61,
#  93,
#  82,
#  93,
#  71,
#  95,
#  71,
#  78,
#  80,
#  88,
#  76,
#  80,
#  61,
#  95,
#  75,
#  60,
#  60,
#  87,
#  79,
#  91,
#  79,
#  75,
#  86,
#  60,
#  97,
#  66,
#  71,
#  85,
#  71,
#  87,
#  60,
#  85]

# %% [markdown]
# ## Dictionary

# %% [markdown]
# ### Task: Create a dictionary `d1`, in which names as key and scores1 as values

# %%
# your code is here
d1 = {name : score1 for name, score1 in zip(names, scores1)}
d1
# Out:
# {'STU100': 72,
#  'STU101': 85,
#  'STU102': 64,
#  'STU103': 61,
#  'STU104': 78,
#  'STU105': 88,
#  'STU106': 100,
#  'STU107': 99,
#  'STU108': 88,
#  'STU109': 65,
#  'STU110': 75,
#  'STU111': 96,
#  'STU112': 86,
#  'STU113': 82,
#  'STU114': 96,
#  'STU115': 85,
#  'STU116': 96,
#  'STU117': 83,
#  'STU118': 97,
#  'STU119': 85,
#  'STU120': 82,
#  'STU121': 88,
#  'STU122': 73,
#  'STU123': 67,
#  'STU124': 95,
#  'STU125': 76,
#  'STU126': 81,
#  'STU127': 78,
#  'STU128': 70,
#  'STU129': 70,
#  'STU130': 76,
#  'STU131': 72,
#  'STU132': 68,
#  'STU133': 88,
#  'STU134': 71,
#  'STU135': 82,
#  'STU136': 64,
#  'STU137': 81,
#  'STU138': 90,
#  'STU139': 100,
#  'STU140': 90,
#  'STU141': 83,
#  'STU142': 89,
#  'STU143': 98,
#  'STU144': 85,
#  'STU145': 65,
#  'STU146': 83,
#  'STU147': 66}

# %% [markdown]
# ### Task: Print the score of the student with name 'STU136'

# %%
# your code is here
print(d1['STU136'])
# Out:
# 64

# %% [markdown]
# ### Task: Create a dictionary `d2`, in which names as key and scores2 as values

# %%
# your code is here
d2 = {names[x] : scores2[x] for x in range(48)}
d1
# Out:
# {'STU100': 72,
#  'STU101': 85,
#  'STU102': 64,
#  'STU103': 61,
#  'STU104': 78,
#  'STU105': 88,
#  'STU106': 100,
#  'STU107': 99,
#  'STU108': 88,
#  'STU109': 65,
#  'STU110': 75,
#  'STU111': 96,
#  'STU112': 86,
#  'STU113': 82,
#  'STU114': 96,
#  'STU115': 85,
#  'STU116': 96,
#  'STU117': 83,
#  'STU118': 97,
#  'STU119': 85,
#  'STU120': 82,
#  'STU121': 88,
#  'STU122': 73,
#  'STU123': 67,
#  'STU124': 95,
#  'STU125': 76,
#  'STU126': 81,
#  'STU127': 78,
#  'STU128': 70,
#  'STU129': 70,
#  'STU130': 76,
#  'STU131': 72,
#  'STU132': 68,
#  'STU133': 88,
#  'STU134': 71,
#  'STU135': 82,
#  'STU136': 64,
#  'STU137': 81,
#  'STU138': 90,
#  'STU139': 100,
#  'STU140': 90,
#  'STU141': 83,
#  'STU142': 89,
#  'STU143': 98,
#  'STU144': 85,
#  'STU145': 65,
#  'STU146': 83,
#  'STU147': 66}

# %% [markdown]
# Task: Print the names of student whose score is 88

# %%
# your code is here
for name in d2:
    if d2[name] == 88:
        print(name)
# Out:
# STU125

# %% [markdown]
# ### Task: Create a a dictionary `d3`, in which names as key, and a list of scores as value. The list of scores has two elements: the first one is from scores1, and the second one is from scores2.

# %%
# your code is here
d3 = {name : [score1, score2] for name, score1, score2 in zip(names, scores1, scores2)}
print(d3)
# Out:
# {'STU100': [72, 94], 'STU101': [85, 97], 'STU102': [64, 93], 'STU103': [61, 77], 'STU104': [78, 67], 'STU105': [88, 77], 'STU106': [100, 100], 'STU107': [99, 81], 'STU108': [88, 97], 'STU109': [65, 70], 'STU110': [75, 82], 'STU111': [96, 76], 'STU112': [86, 66], 'STU113': [82, 78], 'STU114': [96, 89], 'STU115': [85, 91], 'STU116': [96, 61], 'STU117': [83, 93], 'STU118': [97, 82], 'STU119': [85, 93], 'STU120': [82, 71], 'STU121': [88, 95], 'STU122': [73, 71], 'STU123': [67, 78], 'STU124': [95, 80], 'STU125': [76, 88], 'STU126': [81, 76], 'STU127': [78, 80], 'STU128': [70, 61], 'STU129': [70, 95], 'STU130': [76, 75], 'STU131': [72, 60], 'STU132': [68, 60], 'STU133': [88, 87], 'STU134': [71, 79], 'STU135': [82, 91], 'STU136': [64, 79], 'STU137': [81, 75], 'STU138': [90, 86], 'STU139': [100, 60], 'STU140': [90, 97], 'STU141': [83, 66], 'STU142': [89, 71], 'STU143': [98, 85], 'STU144': [85, 71], 'STU145': [65, 87], 'STU146': [83, 60], 'STU147': [66, 85]}

# %% [markdown]
# ### Task: Find the cluster of students whose scores are all at least 90.

# %%
# your code is here
alumnosA = {alumno : [d3[alumno][0], d3[alumno][1]] for alumno in d3 if d3[alumno][0] >= 90 and d3[alumno][1] >= 90}
alumnosA
# Out:
# {'STU106': [100, 100], 'STU140': [90, 97]}
